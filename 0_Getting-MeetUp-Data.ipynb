# %% [markdown]
# Our first step in analyzing Nashville's MeetUp scene is to scrape the data from the web. Fortunately, MeetUp has a great REST API client that we can use to build our database. Head on over to their (interactive console)[https://secure.meetup.com/meetup_api/console] if you want to see its complete functionality.
#
# For our purposes, **event attendance** is the fundamental piece of data we need to build the graph. In MeetUp terminology, we are after the **Yes RSVPs** individuals make when a MeetUp group organizes an event. This doesn't guarantee their actual attendance, of course, but it's the best proxy we have.
#
# Since we're interested in guiding decisions NOW, we will limit our search to events occuring in the past two years. We also want to get metadata for individual members and groups so that we can enrich our graph once we have it.
#
# Our approach will be: NEW API KEY:
#
# 1. Download a list of all groups in Nashville.
# 2. Download a list of events from the past two years from each group.
# 3. Download a list of all "yes" RSVPs for each event.
# 4. Download metadata for each member ID that RSVPed.

# %%
import pandas as pd
import requests

api_key = '646928682c4b5d6f5f6c782a6b351b29' # for a dummy account

# %% [markdown]
# #### 1. Download a list of all groups in Nashville.

# %% [markdown]
# q = 'https://api.meetup.com/{}/events?'.format(urlname)
# q += '&sign=true&page=200&status=past&only=id,name,status,time,yes_rsvp_count&desc=True'
# q += '&{}'.format(api_key)

# %%
from utils import get_all_groups

groups = get_all_groups('nashville tn', radius=25, write_path=None)

groups.head()
# Out:
# Community Experience Testers - Nashville 'category'
#                                           group_name  num_members  \
# group_id
# 339011                       Nashville Hiking Meetup        18669
# 6335372                             Nashville soccer         3461
# 20040517                  Franklin 40+ Out and About         2105
# 18297014                 Nashville Christian Singles         2074
# 24440003  Outgoing Introverts of Nashville (20 - 35)         2153
#
#           category_id         category_name  organizer_id  \
# group_id
# 339011             23  Outdoors & Adventure       4353803
# 6335372            32   Sports & Recreation     108448302
# 20040517           31           Socializing     115037452
# 18297014           23  Outdoors & Adventure     183268581
# 24440003           31           Socializing     105492502
#
#                                group_urlname
# group_id
# 339011                      nashville-hiking
# 6335372                     Nashville-soccer
# 20040517           Franklin-40-Out-and-About
# 18297014  Nashville-Active-Christian-Singles
# 24440003                           Nashchill

# %% [markdown]
# #### 2. Download a list of events from the past two years from each group.

# %%
from utils import get_events

# %%
events = pd.DataFrame()
#for gp_url in groups.group_urlname:
#    events.append(get_events(gp_url, date_filter_str='2016-10-02'), inplace=True)
for gp_url in groups.group_urlname:
    #print(gp_url)
    events = events.append(get_events(gp_url, date_filter_str='2016-10-22', verbose = True))
# Out:
# nashville-hiking
# Nashville-soccer
# Franklin-40-Out-and-About
# /Users/paulomartinez/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py:6201: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=True'.
#
# To retain the current behavior and silence the warning, pass sort=False
#
#   sort=sort)
# Nashville-Active-Christian-Singles
# Nashchill
# nashville-ux
# steppingoutsocialdance
# nashjs
# Nashville-Tennis-Meetup
# Nashville-NET-User-Group
# Nashville-Blockchain-Meetup
# newintown-890
# NashvilleYoungCrowd
# sexposnashville
# All-Things-Fablous-Black-Professional-Women
# The-Nashville-Microsoft-Azure-Users-Group
# NashBI
# Sunday-Assembly-Nashville
# Nashville-Networking-Business-Luncheon
# horrorfriends
# Tails-of-the-Trail
# PyNash
# nashville-software-beginners
# Tennessee-Golf-Events
# Greater-Nashville-Healthcare-Analytics
# diablos-que-bailan
# Southeast-Golf-Events
# Agile-Nashville-User-Group
# Nashville-Spanish-English-Conversation-Group
# nashvillewriters
# NAGACentral
# dnd-49
# Franklin-Friends-50
# J-Love-Christian-Singles-of-Nashville
# DesignThinkingNashville
# NashvilleWomenProgrammers
# MCBS-Beer
# Middle-Tennessee-Hiking-Outdoor-Meetup
# NashvilleMDUG
# EatLoveNash
# Nashville-Modern-Excel-User-Group
# aawstn
# Bellevue-Friends-ages-21-And-Up
# MOMS-Club-of-Brentwood-2
# code-for-nashville
# Dazzling-Dames-50
# serendipitylabsnashville
# MOMSClubHendersonville
# History-The-Arts
# One-Dharma-Nashville
# North-Nashville-Party-Chicks
# Wine-books-and-board-games
# Multifamily-Investor-Nation-Nashville-TN
# NashAPI
# Dining-With-Friends
# Women-n-Wine-Williamson-County
# Nashville-Data-Engineers
# ManyLoves
# Ladies-Night-Outbook-Club
# Nashville-Dungeon-Delvers
# Nashville-Girls-Group-20s-and-30s
# The-Estuary-Mindfulness-Self-Care-and-Support-Community
# NashvilleFlagFootball
# Nashville-Product-Meetup
# franklin-developer-lunch
# Brentwood-Rowdy-Referral-Networking-Meetup
# Smashville-Singles-Coed-25-40ish
# frenchsocialclubofnashville
# Nashville-Startup-Meetup
# NashvilleBackpacker
# BoostNashvilleBiz
# Greater-Nashville-Networking
# MTN-40
# nashvillephp
# TennesseeVoiceOverExchange
# Network-Middle-Tennessee-Prosperous-Partnerships
# Nashville-Young-Professionals-Meetup
# meetup-group-TXMmcCHL
# Data-Science-Nashville
# nashvillejug
# nashvegans
# Pickleball-MusicCity
# Tennessee-Real-Estate-Investors-Meetup
# East-Nashville-Daytime-Basketball
# Young-African-Professionals-Nashville
# nashvillewinegroup
# All-Things-Angular
# Franklin-Polka-Dot-Powerhouse
# freeCodeCamp-Nashville
# The-Institute-of-Noetic-Sciences-IONS-Nashville
# Nashville-Blockchain-Developers-Network
# Nashville-Settlers-of-Catan-Meetup
# NashvilleWordpress
# atheists-455
# meetup-group-yxkNzslx
# Fabulousfemalesnashville
# Green-and-Lean-Banditas
# Financial-Freedom-Network-of-Nashville
# meetup-group-FtpRCHbj
# The-Amazon-Seller
# Nashville-Black-Millennials
# Nashville-Psychics
# Music-City-Entrepreneurs-Network
# -- No event results for  Music-City-Entrepreneurs-Network
# Random-Events-Nashville
# Conscious-Transformation-Nashville
# Nerds-with-Vaginas-Meetup
# Nashville80sLovers
# AH-HA-Thursday-Little-Friday
# Lesbians-just-want-to-have-fun-Nashville
# TennesseeHikingGroup
# Nashville-Sportbike-Group
# meetup-group-VDxDipmy
# Franklin-Friends-20s-30s
# Nashville-Google-Cloud-Platform-Monthly-Meetup
# -- No event results for  Nashville-Google-Cloud-Platform-Monthly-Meetup
# Tableau-and-BI-for-Nashville
# Girl-Talk-A-Personal-Development-Book-Club
# -- No event results for  Girl-Talk-A-Personal-Development-Book-Club
# West-Coast-Swing-Nashville
# meetup-group-QNGZgQuH
# funhappeningssocialgroup
# Nashville-Grown-up-Geeks
# Nashville-Linux-Users-Group
# Nashville-Social-Singles
# MtJuliet-Hermitage-Happenings-Meetup-For-Friends35
# NY-Giants-Fans-in-Nashville
# Philadelphia-Eagles-Fans-In-Nashville
# Nashville-Newbie-Girls
# Data-Nerds
# artsfriends
# Euchre-in-Nashville
# TennesseSingles
# Dev-Mount-Juliet
# NashGameDev
# Nashville-Entrepreneurs-Network
# Music-City-Millennials
# Nashville-Apprentice-Programmers-Society
# Nashville-Multifamily-Meetup
# Nashville-Kubernetes-Meetup
# Nashville-BarkHappy-Dog-Meetup
# Make-Nashville-Meetup
# nashvr
# Nashville-Gay-Game-Night-Meetup
# MOMSClubWhiteHouse
# MusicCityYP
# Live-Music-Lovers-Meetup
# Nashville-Toastmasters-Meetup
# Developer-Launchpad-Nashville
# Nashville-SEO-Group
# Vanderbilt-Entrepreneurship-Conference
# -- No event results for  Vanderbilt-Entrepreneurship-Conference
# spiritualism-291
# podcaster
# reintn
# Nashville-Knitting-Meetup
# Board-Game-Lovers-Meetup-Group
# CoolSprings-Gay-Mens-Lunch-Group
# Fun-Happenings-Travel-Adventure-Group
# Nashville-Gay-Meetup
# Nashville-Doodles
# NashvilleSocialSports
# Nashville-Glamour-Photography-Meetup-Group
# Nashville-Shambhala-Meditation-Group
# nashrb
# NashvilleMusician
# WOMEN-Word-of-Mouth-Entrepreneurial-Networkers
# Nashville-Christian-Womens-Meetup
# CEOMastermindSE
# LinkedIn-Personified-TN
# Gallatin-Moms-Meetup
# meaningfulconversationsnashville
# Nashville-Metaphysical-New-Age-and-Psychic-Meetup
# Covalence-Nashville-Group
# Nashville-Empowered-Light-Holistic-Expo
# paddleadventuresunlimited
# The-Black-Beer-Experience
# Black-In-Tech-Food-and-Hacking
# Low-Carb-Dining
# -- No event results for  Low-Carb-Dining
# Community-Bible-Reading
# Leads-Likes-Marketing-Meetup-of-Nashville
# -- No event results for  Leads-Likes-Marketing-Meetup-of-Nashville
# vocalists-164
# Urban-League-Young-Professionals-of-Middle-Tennessee
# meetup-group-gnvfWQJt
# Social-Business-Networking-Franklin-Women
# Science-Club-Nashville
# GONGNashville
# Friends-Couples-and-Whatever
# House-Flipping-Investing-Mentor-Nashville
# StartupBlink-Nashville
# Nashville-Spirituality-Meetup
# connectnashville
# Nashville-Catholic-Social-Singles
# GALavant-Outdoors
# ManKind-Project-Nashville
# Nolensville-Area-Lunch-Bunch
# Keto-Klub
# Walk-Talk-Ketosis
# Nashville-Girls-Night-Out-Shopping-Networking-More
# rladies-nashville
# Deal-Makers-Nashville
# TN-ACA-Learn-to-Play-Have-Fun
# Nashville-PLATFORMERS-Video-Gaming-Meetup
# Nashville-International-Group
# DomestiquesCyclingTN
# nashvilledrummingmeditation
# Oneness-Nashville
# Intellectual-Society
# ReikiNashvilleTN
# Nashville-Science-Fiction-Book-Club
# cblroundtable
# Nashville-WOACA
# Franklin-AM-Networking
# Franklin-TN-Social-Group-for-Young-Adults-with-LD
# VMware-User-Group-VMUG
# musiccitybrits
# Shopify-Partners-of-Nashville
# Everything-Holistic
# Nashville-Salesforce-Developer-User-Group
# NSS-Alumni-Association
# Nashville-KDrama-Addicts
# M-U-S-I-C-Networking-Group
# Nashville-Swift-Language-Meetup
# meetup-group-YUCGiuAF
# Women-n-Wine-of-Mount-Juliet
# Middle-Tennessee-Snap-Shots
# Nashville-Investors-Traders-StockTwits-Meetups
# LInterNASHional
# DrinkNDrawNashville
# Nashville-Spiritual-Experiences-Group
# Nashville-Improv-Comedy-Meetup
# Nashville-CocoaHeads
# Nashville-Kayak-Lessons
# Nashville-Travel-Hackers
# living-oil-free-and-plant-strong
# What-the-Pho
# Nashville-Bitcoin-Meetup
# Bellevue-Business-Networking-Meetup
# FUNdamental-Book-Club-Meetup
# Murfreesboro-Women-Entrepreneurs-Meetup
# Objectivist-Philosophers-of-Middle-Tennessee
# Nashville-Clean-Eating-Networking-Group
# Empowering-Emotional-Freedom
# XeroHour-Nashville-Meetup-Group
# Creative-Thinkers-Guild
# Reading-Queer
# StartUpNashville
# DollarsOfDivorce
# Who-Are-You-Really-Anyway-WAYRA-Nashville-Chapter
# Wise-Nashville-Explore-Discover-Give-Back-and-Grow
# Nashville-Startup-Founder-101
# Nashville-Couples-Just-Wanna-Have-Fun
# Beer-and-Bible-Nashville
# Active-Outdoors-Nashville
# nashvilleanimaladvocacy
# nashvillefilmmakers
# Nashville-Ride-Group
# Walking-In-woods
# SCORE-Nashville-Events-Networking-and-Workshops
# Nashville-Scrabble-Meetup
# Women-n-Wine-of-Green-Hills
# unityofnashville
# ProjectHappiness
# Tennessee-RHUG
# The-Nashville-Outdoor-Adventures-Club
# Brentwood-Dance-Class-Meetup
# BellevueAreaMeetup
# Hanging-out-with-the-Girls
# Piano-music-lovers-of-Nashville
# Queens-in-Business-Network-QIB
# North-Nashville-Bible-Study
# M-A-D-Y-Make-A-Date-with-Yourself
# Nashville-Animation-Motion-Design-Meetup
# Green-Hills-Stampin-and-Scrapbooking-Meetup
# Nashville-NFL-Ravens-Football-Meetup
# Nashville-Womens-Support-Network
# Nashville-Keto-Meetup
# Nashville-Craft-Party
# Tennessee-Christian-Chamber-of-Commerce
# Nashville-Wakeboarding-Meetup
# Two-Owners-Walk-Into-A-Meeting-Networking-For-Small-Business
# Nashville-Weight-Loss
# Ethereum-Nashville
# Sandwich-For-The-Homeless
# Nashville-Network-After-Work-Business-Networking-Events
# Beers-Business
# Hiking-Club-of-Nashville-and-Suburbs
# NASHVILLE-SLOW-RIDE
# The-Queer-Life-Nashville
# RfR-Nashville-TN
# Music-City-Tango
# nash-elixir
# Middle-Tennessee-Motorcycle-Riders
# TN-PFS-SFS
# thegoddesswithinnashville
# Center-for-Spiritual-Living-Nashville
# NashSec
# Nashville-Axis-Allies-Meetup
# nashvilleceliacs-org
# A-meetup-group-for-professional-gay-men-40-For-dinner-etc
# Nashville-Music-Programmers
# robotics-71
# Brentwood-TN-Conversational-Spanish-Language-Meetup-Group
# Williamson-County-Republican-Party
# meetup-group-beautyandthebrush
# Nashville-Cross-Culture-Meetup
# Nashville-HAES-and-Intuitive-Eating-Meetup
# Wellness-Nashville
# Connect-Franklin
# Nashville-Toastmasters
# -- No event results for  Nashville-Toastmasters
# Nashville-Fun-Times-Meetup
# meetup-group-kGWCrbFX
# Mediumship-and-Intuitive-Development-Circle-of-Nashville
# Nashville-Classic-and-Contemporary-Fiction-Group-for-women
# Shopify-Nashville
# Beyond-the-Brunch-Drunk-on-Life-Takes-Nashville
# Nashville-Young-Christians
# Middle-Tennesse-Naturists-Nudists
# Calm-Abiding-Meditation-followed-by-Heart-Sutra
# Nashville-International-Travel
# Women-of-Purpose-and-Power
# Nashville-Cyber-Security-for-Control-Systems
# Grace-Business-Networking-Group
# 931-Singles-30s-60s
# Nashville-Synthesizer-Meetup
# Its-a-FIT-Life-Creation-Nashville
# -- No event results for  Its-a-FIT-Life-Creation-Nashville
# Songwriter-Survival-Kit-Nashville
# Pumps-And-Passports-Nashville
# Women-n-Wine-of-Nashville
# NashReact-Meetup
# East-Nashville-Book-Club
# Vegan-Peace
# Nashville-Amnesty-International
# Nashville-Essential-Oils-Meetup
# -- No event results for  Nashville-Essential-Oils-Meetup
# Nashville-Kizomba-Meetup
# Nashville-Sustainability-Events-Group
# nashvilleholisticassociation
# alternative-510
# MusicCityJazzFans
# 40-Christian-Singles-Society
# Sociability-Couples
# Lets-Talk-Brentwood-Toastmasters-Club
# Mount-Juliet-Wilson-County-Hiking-Meetup
# Nashville-Real-Estate-Finance-Community
# Mid-TN-Scrapbooking-Club
# Seekers-of-Williamson-Co
# Big-East-Fork-Center-for-Sustainable-Stewardship
# Middle-Tennessee-Social
# Resist-Nashville
# No-BS-Business-Building-Meetup
# Single-Christ-Followers-of-Nashville
# Nashville-Create-Lasting-Change-Meetup
# Explorer-Chicks-of-Nashville-Adventure-Awaits
# ASK-and-WONDER-NASHVILLE
# Yoga4Nashville
# Nashville-Kayaking-Meetup
# Middle-TN-Fountain-Pen-Club
# Nashville-Functional-Forum
# Nashville-Death-Cafe-June
# Toptal-Coffee-Coworking-Nashville
# Nashville-Landmark-Worldwide-Meetup
# Newcomer-Social-Dance-Night
# Nashville-Tennis-Lessons
# Nashville-Ladies-Volunteering-and-Having-Fun
# Nashville-Cupids-Chase-5K
# the-New-World-is-in-Order
# Nashville-Good-Times-for-do-gooders
# Energy-Healing-Nashville-Ataana-Method-Circle-Bliss
# Nashville-Multifamily-Investing-Academy-Meetup
# meetup-group-TiEtxQpU
# YUPmeetUp
# Nashville-Jewish-Meetup
# Middle-Tennessee-Sierra-Club-Outings-and-Adventures
# Chihuahuas-Nashville
# TarotLights
# Nashville-Ladies-Book-Club
# Thrills-and-Chills-Book-And-Film-Club
# Nashville-German-Meetup-Group
# Elastic-Nashville
# WomenTappedIn
# OpenNashville
# Pagan-Outreach-Support-Group
# Le-Painted-Grape-Nashville-TN
# -- No event results for  Le-Painted-Grape-Nashville-TN
# MRNGTennessee
# Music-Industry-Forum-Who-kNew-Nashville
# DurDemarion
# OCD-Nashville-Peer-Support-Group-Meetup
# Sunday-Meditation-Retreat-1-to-3-hours-your-choice
# Tennessee-Historical-Society
# Prayer-home-fellowship
# Keto-State-of-Mind
# Nashville-Christian-Womans-Social-Meetup
# BrentwoodIBD
# Nashville-Free-Guitar-Lesson-Meetup
# Middle-Tennessee-Mountain-Biking
# Meet-Mount-Juliet-Networking-Happy-Hour-Meetup
# Franklin-Reiki
# Franklin-Books-and-Discussion-Meetup
# Nashville-Nerdy-Girls
# Franklin-40-Fun-Seekers
# Big-East-Fork-Retreat
# Rutherford-Integrity-Networking-Group
# Pleasant-View-Magic-The-Gathering-Meetup
# Nashville-Bulldog-Owners-and-Lovers
# The-Cult-of-Productivity
# Gray-Rangers
# Music-City-Festivals-Nashville
# -- No event results for  Music-City-Festivals-Nashville
# Nashville-Twilio-Talks
# -- No event results for  Nashville-Twilio-Talks
# Nashville-Women-Young-at-Heart-Age
# Nashville-Area-Health-Travel
# meetup-group-VLLCezKh
# Tennessee-Professional-Interpreters-Managing-up
# Creative-Thinkers-Guild-Open-House
# Traveling-Widows-and-Widowers
# meetup-group-OMZgGIox
# Nashville-Design-District-Meetup
# AGEAC-A-New-Vision-of-Life-Nashville-Meetup
# -- No event results for  AGEAC-A-New-Vision-of-Life-Nashville-Meetup
# Brunch-and-Code
# Little-Harpeth-Brewery-Tour
# Nakama-615
# Nashville-Credit-and-Wealth-Building
# Nashville-Socials-and-Events
# NashvilleNetworkingGroup
# Nashville-OCD-Support-Group-for-Friends-Family-Meetup
# Nashville-Skiing-Meetup
# Outdoor-Afro-Nashville
# Nashville-Mindfulness-in-Nature
# Nashville-Puppy-Parties
# Nashville-Urban-Planning-Meet-Up
# LifestyleReboot
# Gaias-Tribe
# Womens-business-network
# Movie-Lovers-Classic-New-and-Foreign-Films
# TuneTownShowChorus
# Isha-Yoga-Inner-Engineering-Nashville-Yoga-Meditation
# Nashville-Lisp-Sync
# nawsug
# Nashville-Beading-and-Jewelry-Design-Meetup
# Nashville-Snowflake-User-Group
# InspiredWomenNashville
# Blues-Dance-Nashville
# youarebadass
# African-American-Christian-Social-Network-50
# weedeaters
# Middle-TN-First-Time-Home-Buyers-Meetup
# Andrews-Group-Travel
# GREEN-Investment-Club-Nashville
# musiccitygeeks
# Thinking-Christians-Book-Club
# Nashville-Torah-Bible-Study
# Nashville-Chess-and-Chat-Meetup
# Old-Hickory-Outdoor-Adventures-Meetup
# Rivergate-Weight-Loss-Meetup
# meetup-group-TVLmBeJc
# Become-the-Elite
# Brentwood-GrowYour-Business-In-Tennessee
# Nashville-Cuddling-Meetup
# -- No event results for  Nashville-Cuddling-Meetup
# artoflivingnashville
# Fierce-Fabulous-Women
# Beginning-Real-Estate-Investing-In-Nashville
# Nashville-Daoist-Taoist-Chinese-Philosophy-Meetup-Group
# Women-Horses
# WCDPTN-Events
# All-Things-German-Book-Club
# Citizens-Climate-Lobby-Franklin
# -- No event results for  Citizens-Climate-Lobby-Franklin
# Nashville-Meditative-Global-Music-Meetup
# Movie-Meet-up-at-Big-East-Fork
# Yarnies-Anonymous-Smyrna
# Women-n-Wine-of-Murfreesboro
# Nashville-Real-Estate-Entrepreneurs
# -- No event results for  Nashville-Real-Estate-Entrepreneurs
# Nashville-Home-Buyers-Meetup
# Her-Heart-Project
# Nashville-Crohns-Disease-and-Ulcerative-Colitis-Meetup
# -- No event results for  Nashville-Crohns-Disease-and-Ulcerative-Colitis-Meetup
# Nashville-Barter
# -- No event results for  Nashville-Barter
# Lama-Dragpa-on-Completely-Disarming-the-Struggle-for-Peace
# Hypnosis-Certification-Course-National-Guild-of-Hypnotists
# Hypnosis-Primer-the-Power-to-Heal
# Mocha-Social-Butterflies-30s-40s
# VIP-Acting-Workshop-Meetups
# meetup-group-ceaDVhDs
# Its-Time-A-30-Something-ish-Missional-Community
# Reiki-Healing-with-Sound-Immersion
# Bitcoin-For-Everyone
# Nashville-Animal-Save
# Nashville-League-of-Legends-Meetup
# Not-So-Valentines-Day-Singles-Meet-Up
# Murfreesboro-Charity-Fiber-Arts-Meetup
# Zero-Waste-Nashville
# Nashville-Gaming-Meetup
# Design-the-Life-of-Your-Dreams
# -- No event results for  Design-the-Life-of-Your-Dreams
# Mammoth-Cave-exploring
# Nashville-Sustainable-Development-Meetup
# -- No event results for  Nashville-Sustainable-Development-Meetup
# nashville-marketing
# Girl-Develop-It-Nashville
# 20-30somethingcouplesNashville
# Back-to-Health-Lifestyle
# Nashville-Professional-Photography-Meetup-by-ASMP-Nashville
# Science-Religion
# Visually-Impaired-Activity-Social-Club
# -- No event results for  Visually-Impaired-Activity-Social-Club
# Lesbian-and-Bisexual-Women-Creatives-of-Nashville
# Nashville-Media-Tech
# -- No event results for  Nashville-Media-Tech
# The-20-Somethings-Tennis-League-Nashville
# Money-Men-and-Mimosas
# FREE-WINTER-OPEN-HOUSE
# Nashville-SaltStack-Users-Group
# Nashville-Tennessee-Brand-Marketers-Agency-Professionals
# SavvyCoders
# Music-city-women-of-courage-strength
# Padmasambhava-Buddhist-Center-Nashville
# Nashville-Social-Networking-Meetup
# Nashville-Blockchain-and-Digital-Media
# -- No event results for  Nashville-Blockchain-and-Digital-Media
# Customer-Experience-Professionals-Meetup
# Nashville-Christian-Ministry-Meetup
# Flirty-30s-of-Nashville
# Nashville-Scrum-Masters-Guild
# -- No event results for  Nashville-Scrum-Masters-Guild
# Girl-Friends-Hanging-Out
# Are-you-ready-to-fall-into-change
# Nashville-Fights-Against-Alzheimer-Walk-to-EndALZ
# Startup-Grind-Nashville
# Music-Industry-Nashville
# IIBA-Nashville-Chapter-Meetup
# Nashville-Bhakti-Yoga-Meetup
# meetup-group-PGeQHqoj
# Nashville-Artists-Art-Show-Networking-Meetup
# NashvilleFreelanceCreatives
# Open-Mainframe-Project
# -- No event results for  Open-Mainframe-Project
# Nashville-TENNISseans
# Karate-at-the-Park
# The-Costumed-Revelers
# Achilles-Nashville-Hope-Possibility-5-Miler-and-1-Mile-Run
# West-Meade-Cyclists
# Nashville-Tennessee-Volunteers-Viewing-Parties-Meetup
# Middle-Tennessee-HEMA
# Back-Road-Bikers
# Mental-Health-Counseling-Professionals-in-Private-Practice
# 4GenNow-Nashville
# Nashville-Dynatrace-User-Group
# Middle-TN-Kayak-Lessons-Meetup
# Nashville-Tennis-Lessons-PYC
# Nasvhille-Bitcoin-Crypto-Meetup
# meetup-group-qTWwMeMm
# The-Leadership-Circle
# meetup-group-adTZVUra
# -- No event results for  meetup-group-adTZVUra
# Nashville-Cardinals-Club
# Advanced-Audio-Applications-Exchange-A3E-Nashville
# Blockchain-Technology-Disrupting-Healthcare
# French-Toastmasters-club
# Lipscomb-Environmental-Sustainability-Meetup
# Nashville-QA
# Craft-Beer-Lovers-of-Nashville-Meetup
# Nashville-Podcasting-for-Music-Business
# Nashville-Fishing-Meetup
# Detroit-Red-Wings-Fans-in-Nashville-Meetup
# Nashville-Feminist-Meetup
# Nashville-Tennessee-Magento
# Analytics-At-Speed-Nashville
# Nashville-Screenwriters-Meetup
# Ingress
# Shopify-Entrepreneurs-of-Nashville
# Nashville-Wanderlusters
# Bi-Tennessee
# Nashvilles-House-of-Poets
# CaliforniaRelocation
# Nashville-Artificial-Intelligence-Society
# Nashville-Apache-Kafka-Meetup-by-Confluent
# -- No event results for  Nashville-Apache-Kafka-Meetup-by-Confluent
# UU-Moms
# Nashville-Real-Estate-Investor-Entourage
# Nashville-EOS-Meetup
# -- No event results for  Nashville-EOS-Meetup
# Nashville-IAM-Workshop-Series-Meetup
# -- No event results for  Nashville-IAM-Workshop-Series-Meetup
# Nashville-Artist-Managers
# Nude-Dudes-Nashville
# -- No event results for  Nude-Dudes-Nashville
# ronpaul-69
# MusicCitySingles
# James-K-Polk-Toastmasters
# SmileDirectClub
# E3-Nashville-Engagement-Enlightenment-Empowerment
# -- No event results for  E3-Nashville-Engagement-Enlightenment-Empowerment
# Nashville-social-Greeks
# -- No event results for  Nashville-social-Greeks
# Nashville-PowerShell-User-Group
# LibertyOnTheRocks-TN
# SupNashville
# NashvilleWebDesign
# -- No event results for  NashvilleWebDesign
# spanish-570
# Nashville-Hadoop-Meetup
# TheManProject
# mamamoja
# -- No event results for  mamamoja
# Nashville-Backgammon-Association
# Meteor-Nashville
# Ambrosia-Friends-Food-and-Fun
# Nashville-Lefties
# On-Sundays-We-Brunch-Young-Black-Professionals
# Middle-TN-Business-Meetup
# -- No event results for  Middle-TN-Business-Meetup
# Nashvilles-New-Business-Owners
# litegroupnashville
# Nashville-com
# Nashville-Tennessee-IT-Security
# Nashville-Big-Data-and-Analytics-Meetup
# -- No event results for  Nashville-Big-Data-and-Analytics-Meetup
# Nashville-Muslim-Meetup
# Viva-ItaliaTN
# Nashville-International-Relations-Meetup-Great-Decisions
# Bitches-Who-Brunch-Nashville
# Diner-en-Blanc-Music-City-Interest-Group
# nashville-seo-meetup
# Nashville-Software-Defined-Networks
# Nashville-Farm-to-Fork
# Latinas-en-Nashville
# I-Want-To-Hear-Your-Story
# BearCats-Happy-Hour
# Nashville-Startup-Idea-to-IPO
# Dine-and-Unwind-in-East-Nashville
# East-Side-Tribe
# Nashville-Tech
# nashfsharp
# Nashville-Children-in-Nature
# Nashville-Digital-Marketing-Meetup
# Nashville-SEO
# Nashville-Gay-Nudist-Meetup
# East-Nashville-Social-For-Millenials
# Nashville-Golf-Meetup-For-Millennials
# -- No event results for  Nashville-Golf-Meetup-For-Millennials
# meetup-group-rATAOgVk
# Eastside-Rides
# Nashville-Sailing
# meetup-group-hKceZQRh
# SingleintheCityLive
# Nashville-Psychotherapy-Institute
# Nashville-Rock-Blues-and-Jazz-Musicians-Singers
# skeletoncru
# InVenture-Scouts
# 7edfeebb-9e66-45f8-af00-98aaefa48900
# Nashville-single-mums-in-30s
# Nashville-Pilgrimage-Walking-Meetup-Group
# Strictly-Belcourt
# SEO-Nashville
# Nashville-Hearthstone-Fireside-Gathering
# NashMicro
# Nashville-Real-Estate-Investing-Marketing-Entrepreneurs
# Nashville-Pick-a-Flick
# Nashville-Christian-Technologists-and-Entrepreneurs
# HardwareNash
# -- No event results for  HardwareNash
# Asurion-Veterans-Service-Group-Meetup
# Business-Girls-Rock-Nashville-Entrepreneurship-Meetup
# Conscious-Nashville
# Weekday-Daytime-Connections
# tennesseeau
# Gastro-Sojourn
# NashvilleNetworking
# spiritist-study-group
# New-Moon-Monthly-Energy-Workshop
# WomensGoldfiguresclub
# Untitled-A-Writing-Group
# NashvilleCryptocurrencyMeetup
# ACIM-Fellowship
# Build-and-Develop-Your-Online-Presence-Nashville-TN
# nashvillegrammar
# Nashville-Naturals
# 372WN-Magazine-presents-West-Nashville
# -- No event results for  372WN-Magazine-presents-West-Nashville
# theNSO
# Shelbybyoga
# Nashville_Atlassian_Group
# thenashvilletaijiclub
# Nashville-Silent-Meditation-Meetup
# Nashville-Contra-Dancers
# Village-Healing-Arts
# women-wine-and-coloring
# CCLNashville
# Nashville-Muslim-Convert-Support-Meetup
# -- No event results for  Nashville-Muslim-Convert-Support-Meetup
# Antioch-Charismatic-Liberals
# CPATGroup
# Nashville-Nonprofit-Meetup
# Nashville-NLP-Hypnosis-Meetup
# nashville-online
# bizwomenrock
# Nashville-Professionals-Networking-Connection
# NashvilleIceBreakers
# Nashville-Cohousing-Group
# PROVIDENTLIVING
# Nashville-Area-Real-Estate-Investors-Meetup
# Nashville-Parents-of-Children-with-Dyslexia-Support-Group
# A-bucketlisted-life-com
# Stand-Up-Paddle-Boarding-in-Nashville-TN
# Serial-Tanks
# Networking-for-Charity
# No-Mommys-Perfect
# The-Nashville-Girly-Book-Club
# ACE-MidTN
# nashvillelocals
# Country-Dancers-And-People-Who-Love-To-Party
# A-Course-in-Miracles-Nashville-Meetup
# Nashville-Meditation-and-Hypnosis
# MCWhiskeySociety
# The-Data-Warehouse-Institute-TDWI-Nashville-Meetup
# Nashville-30s-and-40s-Meetup
# Nashville-Photography-Model-Events-Meetup-Group
# Nashville-Music-Performance-Playground
# Nashville-Designers-Guild
# -- No event results for  Nashville-Designers-Guild
# Nashville-Travel-Meetup
# Nashville-Startups
# livemusicnashville
# Nashville-Digital-Entrepreneurs-Free-Marketing-Classes
# -- No event results for  Nashville-Digital-Entrepreneurs-Free-Marketing-Classes
# Nashville-Professionals-Networking-Group
# PlanetX
# Enneagram-Nashville
# For-Women-Only-How-to-Not-Run-Out-of-Cash-in-Retirement
# Brentwood-Happy-Hour-Dining-Out-Meetup
# Nashville-Business-Women-Bringing-Everyday-Style
# nashville-docker
# InkwellBasics
# SecularLife
# The-Community-for-Growth-and-Healing
# -- No event results for  The-Community-for-Growth-and-Healing
# Souls-in-Recovery-Nashville-Mental-Health-Recovery-Meetup
# psociety
# Extraterrestrials
# rawfood-152
# The-Nashville-Sushi-Meetup-Group
# Nashville-Build-Your-Home-Club
# Nashville-Flight-Training
# Memorial-Day-Weekend
# WholeWealthClub
# Hermitage-Golf-Meetup
# -- No event results for  Hermitage-Golf-Meetup
# Earth-Alliance
# -- No event results for  Earth-Alliance
# Hermitage-Musical-Notation-Meetup
# Hermitage-Old-Hickory-Mt-Juliet-World-of-Warcraft-Meetup
# HermitageCampHike
# girlsnightoutclub
# LGBT-Meetup-and-friends
# Goodlettsville-Roadrunners
# Middle-Tennessee-Geocaching-Society
# Nine-12-Project-Nashville
# Resist-Brentwood
# The-Brentwood-Glenn-Beck-Meetup-Group
# Funnel-Hackers-Nashville
# -- No event results for  Funnel-Hackers-Nashville
# Pregnant-and-New-Moms-Group
# JOBS-Etc-Career-Opportunities-Network
# sales-149
# Middle-Tenn-Tennis-Connections
# -- No event results for  Middle-Tenn-Tennis-Connections
# Nashville-chapter-of-The-NADP
# -- No event results for  Nashville-chapter-of-The-NADP
# Texans-in-Middle-Tennessee
# Soul-Evolution-Ascension-Beyond-Of-Nashville
# Brentwood-Bible-Study
# IamHappyProjectBrentwoodTN
# Nashville-LeanSixSigma-Meetup
# -- No event results for  Nashville-LeanSixSigma-Meetup
# NashvilleMobileDotNet
# Williamson-County-IT-Professionals
# 912ProjectTN
# Interfaith-Scripture-Study
# Brentwood-Artificial-Intelligence-Meetup
# Living-Wholeheartedly-The-Daring-Way-Nashville
# Nashville-Insurance-Professionals
# Resist-Antioch
# Home-School-Support-Meetup
# -- No event results for  Home-School-Support-Meetup
# Victoriana-Afternoon-Tea-Society
# Nashville-Young-Survival-Coalition-Face-2-Face-Networking
# Nashville-World-Travelers
# MasterClasses
# NashvilleIAM
# volunteernashville
# Nashville-Cooking-Lessons-Meetup
# Humanist-Association-MiddleTN
# FoundingMoms-Nashville
# RF-FOMO-in-TN
# Aussies-in-Nashville
# Nashville-Business-Strategy-Meetup
# West-Nashville-Conversation-Cafe
# Nashville-R-Users-Group
# MyNMBBB
# Hendersonville-Walking-Meetup
# meetup-group-HdmmwCyA
# Volunteers-of-Nashville-and-Beyond
# Everything-Keto
# -- No event results for  Everything-Keto
# Hendersonville-Parents-of-Kids-with-Aspergers-Meetup
# -- No event results for  Hendersonville-Parents-of-Kids-with-Aspergers-Meetup
# Sumner-County-Secular-Homeschool-Meetup
# Hendersonville-Dining-Out-Meet-Up
# Sumner-County-Libertarian-Party
# Hendersonville-Camping-Meetup
# -- No event results for  Hendersonville-Camping-Meetup
# Hendersonville-Area-Active-Outdoor-Lifestyle
# Hendersonville-Conservative-American-Moderation-Meetup
# -- No event results for  Hendersonville-Conservative-American-Moderation-Meetup
# Hendersonville-Mindfulness-Meditation-Meetup
# SoulScaped-Living
# Kundalini-Yoga-Meditation-Mount-Juliet-Tn
# -- No event results for  Kundalini-Yoga-Meditation-Mount-Juliet-Tn
# DrugFree-Wilco
# -- No event results for  DrugFree-Wilco
# Mount-Juliet-Exercise-Meetup
# -- No event results for  Mount-Juliet-Exercise-Meetup
# Mount-Juliet-Titans-Fans
# Wilson-County-Real-Estate-Investment-Group
# Wilson-County-Women-Volunteering-and-Having-Fun
# Mount-Juliet-Supper-Club
# Kindness-as-the-Ultimate-Expression-of-Self-Love
# -- No event results for  Kindness-as-the-Ultimate-Expression-of-Self-Love
# meetup-group-KuYyZLuP
# Nashvilles-Elite-Wine-Travel-2-0
# Healthy-Fit-Fabulous
# Williamson-County-Mobile-Developers
# Franklin-Dining-Out-Meetup
# -- No event results for  Franklin-Dining-Out-Meetup
# SOWBO_Nashville
# Real-Estate-Investors-of-Williamson-County-How-to-succeed
# Bible-Reading
# MHO-Nashville-Active-Adventures
# Organ-Transplant-Support-Group
# -- No event results for  Organ-Transplant-Support-Group
# Franklin-Happy-Hour-Meetup
# Resist-Franklin
# Nashville-Computer-Science-Meetup
# New-Franklin-Locals
# -- No event results for  New-Franklin-Locals
# Franklin-Lets-start-a-20s-ministry
# Williamson-County-Ruby-Meetup
# Morse-Entrepreneur-Mastermind
# Franklin-Dogs
# -- No event results for  Franklin-Dogs
# Nashville-Machine-Learning-Meetup
# Franklin-Republican-Party-Meetup
# -- No event results for  Franklin-Republican-Party-Meetup
# Arts-Council-of-Williamson-County
# Feminie-Rejuvenation-Incontinence-Seminar
# RED-Dont-Settle-You-Matter-Join-the-Fight
# Franklin-Small-Business-Digital-Media-Marketing-Meetup
# Franklin-Traditional-Irish-Music-Meetup
# Franklin-Singles-Fellowship
# Big-East-Fork-Hiking-Breakfast-Club
# Franklin-Technology-Startups-Meetup
# Big-East-Fork-Yoga-Mind-Body-and-Wellness
# Franklin-Natural-Health-Group
# Franklin-Essential-Oils-Meetup
# Franklin-Tai-Chi-Qi-Gong-Meetup
# ML-JP-Dance-Music-Family
# Inclusive-Families-of-Rutherford-Co
# Home-Buyers-of-Rutherford
# Smyrna-Yoga-Zumba-Boot-Camp-Women-Only
# Coaching-Circle-Triage-Meetup
# -- No event results for  Coaching-Circle-Triage-Meetup
# Gallatin-WordPress-Meetup
# -- No event results for  Gallatin-WordPress-Meetup
# SumnerCountyShooters
# middletennesseecycling
# GallatinMakerspace
# Growing-Business-Through-Networking
# Sou-sou-west-Happy-Hour-for-Freelance-Creatives
# First-District-Conservatives
# -- No event results for  First-District-Conservatives

# %%
events.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 25867 entries, 0 to 4
# Data columns (total 6 columns):
# group_urlname     25867 non-null object
# id                25867 non-null object
# name              25867 non-null object
# status            20293 non-null object
# time              25867 non-null datetime64[ns]
# yes_rsvp_count    25867 non-null object
# dtypes: datetime64[ns](1), object(5)
# memory usage: 1.4+ MB

# %%
events.head()
# Out:
#       group_urlname            id  \
# 0  nashville-hiking     253584350
# 1  nashville-hiking  zxqrgqyxnbbc
# 2  nashville-hiking     255586555
# 3  nashville-hiking  hnfqdqyxnbxb
# 4  nashville-hiking     254588203
#
#                                                 name status  \
# 0  Marcella Vivrette Smith Park - moderate to str...   past
# 1        Fontanel Hike then lunch at Cafe Fontanella   past
# 2         Happy Brain, Healthy Body: Nature Workshop   past
# 3                     Edwin Warner Park Evening Hike   past
# 4  Group Volunteering at Second Harvest Food Bank...   past
#
#                  time yes_rsvp_count
# 0 2018-10-21 14:15:00             21
# 1 2018-10-20 14:00:00             20
# 2 2018-10-20 12:30:00              1
# 3 2018-10-18 23:00:00             22
# 4 2018-10-16 22:30:00             11

# %% [markdown]
# #### 3. Download a list of all "yes" RSVPs for each event.

# %%
for event_id, gp_url in events.head().group_urlname.iteritems():
    print(event_id, gp_url)
# Out:
# 0 nashville-hiking
# 1 nashville-hiking
# 2 nashville-hiking
# 3 nashville-hiking
# 4 nashville-hiking

# %%
from utils import get_all_event_rsvps

rsvps = pd.DataFrame()
for event_id, gp_url in events.group_urlname.iteritems():
    rsvps.append(get_all_event_rsvps(gp_url, event_id, api_key), inplace=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-5ced01dfd430> in <module>()
#       3 rsvps = pd.DataFrame()
#       4 for event_id, gp_url in events.group_urlname.iteritems():
# ----> 5     rsvps.append(get_all_event_rsvps(gp_url, event_id, api_key), inplace=True)
#
# ~/Git/meetup-netx/nashnetx/utils.py in get_all_event_rsvps(urlname, list_of_event_ids, api_key)
#     165     '''Accepts a group urlname and list of event ids, and returns a DataFrame of RSVPs. '''
#     166     all_rsvp_df = pd.DataFrame(columns=['group_urlname', 'event_id', 'member_id'])
# --> 167     for eid in list_of_event_ids:
#     168         tdf = get_event_rsvps(urlname, eid, api_key)
#     169         all_rsvp_df = all_rsvp_df.append(tdf, ignore_index=True)
#
# TypeError: 'int' object is not iterable

# %% [markdown]
# #### 4. Download metadata for each member ID that RSVPed.

# %%
unique_members = rsvps.member_id.unique()

# %% [markdown]
# ## Run Data

# %%
# read in membership data and trim to "recent" visits
edges = pd.read_csv('data\\memberships.csv', parse_dates=['joined','visited'])
# edges = edges.loc[edges.visited > pd.to_datetime('2016-01-01')]

# create a "members" dataset
members = edges[['member_id', 'name', 'hometown', 'city','state', 'lat', 'lon']].groupby('member_id').first()
members['num_groups'] = edges[['member_id']].groupby('member_id').size()

# read in group information and trim down to only groups with edges
groups = pd.read_csv('data\\groups.csv', index_col='group_id')
groups = groups.loc[edges.group_id.unique()]

# %%
all_events_filename = './data/events.csv'
all_rsvps_filename = './data/rsvps.csv'

if not os.path.exists(all_events_filename):
    (pd.DataFrame(columns=['event_id', 'name', 'status', 'time', 'yes_rsvp_count', 'group_urlname'])
         .to_csv(all_events_filename, header=True, index=None) )
if not os.path.exists(all_rsvps_filename):
    (pd.DataFrame(columns=['group_urlname', 'event_id', 'member_id'])
         .to_csv(all_rsvps_filename, header=True, index=None) )

for i, g in groups.dropna().iloc[712:].iterrows():
    try:
        print(g.group_name)
        events = get_events(g.group_urlname, api_key, date_filter_str='2015-11-01')
        rsvps = get_all_event_rsvps(g.group_urlname, events.id.tolist(), api_key)
        
        events.to_csv(all_events_filename, header=False, mode='a', index=None)
        rsvps.to_csv(all_rsvps_filename, header=False, mode='a', index=None)
        sleep(1)
    except ValueError as exc:
        print(exc)
    except ConnectionError as exc:
        print(exc)
    finally:
        if 'events' in dir(): 
            del events
        if 'rsvps' in dir():
            del rsvps

# %%
# Nashville Improv & Comedy Meetup
# Nasville Slow Ride

# %%
# from time import sleep
# import json

# edges = pd.DataFrame()
# err_ids = []
# for pid in members.index:
#     r = requests.get('https://api.meetup.com/2/groups?&sign=true&member_id={}&page=200&key=1eb16676d664fa48314391ae5b6c'.format(pid))
#     try:
#         r = r.json()
#         for membership in r['results']:
#             edge = pd.Series({'member_id': pid, 
#                               'group_id': membership['id'], 
#                               'group_name': membership['name']})
#             edges = edges.append(edge, ignore_index=True)
#     except json.decoder.JSONDecodeError:
#         print(pid)
#         err_ids.append(pid)
    
#     # Sleep briefly so that API doesn't get overwhelmed
#     sleep(0.2)
        

# # Write to computer
# write_data = True
# if write_data == True:
#     edges.to_csv('data_edges.csv')

# %%
import pathlib
import pandas as pd

data_files = [x for x in pathlib.Path('data').iterdir()]
events = pd.read_csv('data/events.csv')
members = pd.read_csv('data/members.csv')
groups = pd.read_csv('data/groups.csv')

rsvps = pd.read_csv('data/rsvps.csv')

# %%
import matplotlib.pyplot as plt

# %%
rsvps_full = rsvps.merge(events[['event_id', 'group_urlname']], on='event_id', how='left')
#.merge(members, on='member_id', how='left', suffixes=('_event', '_member'))

group_attendance = rsvps_full.groupby(['member_id', 'group_urlname']).size()
group_attendance_trimmed = group_attendance.loc[group_attendance>0].reset_index()
mgdf = group_attendance_trimmed.merge(groups[['group_id', 'group_urlname']], on='group_urlname')
mgdf = mgdf.rename(columns={0: 'weight'})[['member_id', 'group_id', 'weight']]

# %%
mgdf.to_csv('data/member-to-group-edges.csv', index=None)

# %%
g = nx.from_pandas_edgelist(mgdf, 'member_id', 'group_id', 'weight')
Gc = max(nx.connected_component_subgraphs(g), key=len)
member_nodes, group_nodes = nx.bipartite.sets(Gc)

mg = nx.bipartite.weighted_projected_graph(Gc, nodes=member_nodes, ratio=False)
gg = nx.bipartite.weighted_projected_graph(Gc, nodes=group_nodes, ratio=False)

# %%
len(mg.nodes)

# %%
df = nx.to_pandas_edgelist(mg, source='member1', target='member2')

# %%
df.to_csv('data/member_edges.csv')

# %%
groups = groups.set_index('group_id').loc[[x for x in g.nodes]]

# %%
groups.sort_values(by='num_members', ascending=False)

# %%
groups.loc[groups.group_name=='PyNash']

# %% [markdown]
# # Working on Pynash

# %%
import networkx as nx 
import pandas as pd

df = pd.read_csv('data/group_edges.csv')
g = nx.from_pandas_edgelist(df, source='group1', target='group2', edge_attr='weight')

# %%
nx.spring_layout?

# %%
import matplotlib.pyplot as plt
import seaborn as sns 

colors = sns.color_palette('muted')

# %%
pynash_nodes = [11625832] + [x for x in g[11625832].keys()]

fig, ax = plt.subplots(1,1,figsize=(5,5), dpi=150)

pos = nx.spring_layout(g.subgraph(pynash_nodes), k=3)
nx.draw_networkx_edges(g.subgraph(pynash_nodes), pos, with_labels=False,
                 width=0.1, alpha=0.5)
nx.draw_networkx_nodes(g.subgraph(pynash_nodes), pos, with_labels=False,
                 node_color=colors[0], node_size=100, alpha=0.9)
nx.draw_networkx_nodes(g, pos, nodelist=[11625832], node_color=colors[1])

plt.axis('off')

plt.show()

# %%
nx.draw_networkx?

# %%
groups.loc[[25903892, 1505523, 1585196, 11625832]]

# %%
groups['clustering'] = pd.Series(nx.clustering(g, weight='weight'))

# %%
groups.groupby('category_name').clustering.mean().index

# %%
fig, ax = plt.subplots(1,1, figsize=(4,8))

cats_to_use = groups.groupby('category_name').size().sort_values().iloc[15:].index
sns.barplot(data=groups.loc[groups.category_name.isin(cats_to_use)], 
            y='category_name', x='clustering', 
              order = (groups.loc[groups.category_name.isin(cats_to_use)]
                           .groupby('category_name').clustering.median()
                           .sort_values().index),
              ax=ax)
ax.set_yticklabels(ax.get_yticklabels(), fontsize=20, ha='right')
ax.set_ylabel('')
ax.set_title('Clustering Coefficient\nBy Category', fontsize=28)
plt.show()

# %%
pynash_revelers = nx.shortest_path(g, source=25903892, target=11625832)
gsub = g.subgraph(pynash_revelers)
label_dict = groups.loc[pynash_revelers, 'group_name'].to_dict()

fig, ax = plt.subplots(1,1,figsize=(5,5), dpi=150)

pos = nx.circular_layout(gsub)
nx.draw_networkx_edges(gsub, pos, width=5, alpha=0.5)
nx.draw_networkx_nodes(gsub, pos, with_labels=True,
                 node_color=colors[0], node_size=1000, alpha=1)
nx.draw_networkx_nodes(gsub, pos, nodelist=[11625832], node_color=colors[1])
nx.draw_networkx_labels(gsub, pos, labels=label_dict)

plt.axis('off')

plt.show()

# %%
groups.loc[[x for x in g[11625832].keys()]].category_name.value_counts()

# %%
cent = nx.betweenness_centrality(g, weight=None, normalized=True)
groups['centrality'] = pd.Series(cent)
groups['degree'] = pd.Series(dict(nx.degree(g)))

# %%
cent_names = groups.loc[[x for x in g.nodes]].sort_values(by='centrality', ascending=False)
cent_names.loc[cent_names.centrality>0, ['group_name', 'category_name', 'centrality']].head(8)

# %%
list(ax.get_xticklabels())

# %%
fig, ax = plt.subplots(1,1,figsize=(8,5), dpi=150)

sns.regplot(data=groups, x='num_members', y='centrality', order=1, ax=ax)
ax.set_xlim([0,6500])

textprops = {'fontsize': 18}
ax.set_xlabel('Number of Members', **textprops)
ax.set_ylabel('Centrality', **textprops)
#ax.set_xticklabels(ax.get_xticklabels(), fontsize=14)
#ax.set_yticklabels(ax.get_yticklabels(), fontsize=14)

#x.set_frame_on(False)

plt.show()

# %%
fig, ax = plt.subplots(1,1,figsize=(8,5), dpi=150)

sns.regplot(data=groups, x='clustering', y='centrality', logx=True, ax=ax)
#ax.set_xlim([0,6500])

textprops = {'fontsize': 18}
ax.set_xlabel('Number of Members', **textprops)
ax.set_ylabel('Centrality', **textprops)
#ax.set_xticklabels(ax.get_xticklabels(), fontsize=14)
#ax.set_yticklabels(ax.get_yticklabels(), fontsize=14)

#x.set_frame_on(False)

plt.show()

# %%
nx.betweenness_centrality?

# %%
import seaborn as sns 

fig, ax = plt.subplots(1,1, dpi=300)

sns.kdeplot(np.array(ws), kernel='gau', bw=2, shade=True, ax=ax)
ax.set_xlim([0,15])
ax.set_frame_on(True)
ax.set_title('Distribution of Edge Weights', fontsize=24)
ax.vlines(2.3, 0, 1, linestyle='--')
ax.set_yticks([0.05, 0.1, 0.15, 0.2])
ax.set_yticklabels(['5%', '10%', '15%'])
ax.set_ylim([0,0.2])
ax.annotate(xy=(4, 0.15), s='Mean Shared Members\nis 2.3', fontsize=18)
plt.show()

# %%
import pandas as pd

df = pd.read_csv('data/member-to-group-edges.csv')
len(df.group_id.unique())

# %%
groups = pd.read_csv('data/groups.csv')
members = pd.read_csv('data/members.csv')
events = pd.read_csv('data/events.csv')
rsvps = pd.read_csv('data/rsvps.csv')

# %%
groups.loc[groups.group_id.isin(df.group_id.unique())].to_csv('kaggle/meta-groups.csv', index=None)
members.loc[members.member_id.isin(df.member_id.unique())].to_csv('kaggle/meta-members.csv', index=None)

ev  = events.merge(groups[['group_id', 'group_urlname']], on='group_urlname')[['event_id', 'group_id', 'name', 'time']]
ev.loc[ev.group_id.isin(df.group_id.unique())].to_csv('kaggle/meta-events.csv', index=None)

# %%
rp = rsvps.loc[rsvps.event_id.isin(ev.event_id.unique()) & rsvps.member_id.isin(df.member_id.unique())]
rp.merge(ev[['event_id', 'group_id']], on='event_id').to_csv('kaggle/rsvps.csv')
